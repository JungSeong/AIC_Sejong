# %% [markdown]
# # AIS YOLO SC Pose Train
#
# SC port bbox 1개와 visible SC frame의 4개 corner keypoint를 학습합니다.
#
# Assumption:
# - YOLO pose label format: `class x_center y_center width height kpt0_x kpt0_y ... kpt3_x kpt3_y`
# - keypoint order: `sc_top_left, sc_top_right, sc_bottom_right, sc_bottom_left`
# - corner 순서가 뒤집히면 학습 결과가 바로 나빠지므로 annotation 쪽 순서와 이 노트북의 `KEYPOINT_NAMES`를 반드시 맞춥니다.

# %%
from pathlib import Path
import random

import yaml


def find_src_root(start: Path) -> Path:
    for path in [start, *start.parents]:
        if (path / "pixi.toml").exists() and (path / "ais").exists():
            return path
        nested_src = path / "ws_aic" / "src"
        if (nested_src / "pixi.toml").exists() and (nested_src / "ais").exists():
            return nested_src
    raise RuntimeError("ws_aic/src root를 찾지 못했습니다. 노트북을 ws_aic/src 아래에서 실행하세요.")


SRC_ROOT = find_src_root(Path.cwd().resolve())
WS_ROOT = SRC_ROOT.parent

DATASET_DIR = WS_ROOT / "data" / "yolo" / "approach" / "SC"
DATA_YAML = DATASET_DIR / "data.yaml"

KEYPOINT_DIMS = 2
KEYPOINT_NAMES = [
    "sc_top_left",
    "sc_top_right",
    "sc_bottom_right",
    "sc_bottom_left",
]
CLASS_NAMES = {0: "sc_port"}
IMAGE_EXTS = {".bmp", ".jpeg", ".jpg", ".png", ".tif", ".tiff", ".webp"}

print(f"SRC_ROOT: {SRC_ROOT}")
print(f"DATASET_DIR: {DATASET_DIR}")
print(f"DATA_YAML: {DATA_YAML}")
# Out:
# SRC_ROOT: /home/whyz/aic_sejong/ws_aic/src
# DATASET_DIR: /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC
# DATA_YAML: /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/data.yaml

# %% [markdown]
# ## Dataset yaml
#
# Ultralytics pose dataset 설정을 생성합니다. 라벨이 이미 준비된 뒤 실행하세요.

# %%
dataset_cfg = {
    "path": str(DATASET_DIR),
    "train": "images/train",
    "val": "images/val",
    "kpt_shape": [len(KEYPOINT_NAMES), KEYPOINT_DIMS],
    "flip_idx": list(range(len(KEYPOINT_NAMES))),
    "names": CLASS_NAMES,
    "kpt_names": {0: KEYPOINT_NAMES},
}

DATASET_DIR.mkdir(parents=True, exist_ok=True)
DATA_YAML.write_text(yaml.safe_dump(dataset_cfg, sort_keys=False, allow_unicode=True), encoding="utf-8")
print(DATA_YAML.read_text(encoding="utf-8"))
# Out:
# path: /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC
# train: images/train
# val: images/val
# kpt_shape:
# - 4
# - 2
# flip_idx:
# - 0
# - 1
# - 2
# - 3
# names:
#   0: sc_port
# kpt_names:
#   0:
#   - sc_top_left
#   - sc_top_right
#   - sc_bottom_right
#   - sc_bottom_left

# %% [markdown]
# ## Label check
#
# 학습 전에 이미지/라벨 개수와 YOLO pose 라벨 컬럼 수를 확인합니다.

# %%
def resolve_split_dir(cfg: dict, split: str) -> Path:
    split_path = Path(cfg[split]).expanduser()
    if split_path.is_absolute():
        return split_path

    root = Path(cfg.get("path", DATA_YAML.parent)).expanduser()
    if not root.is_absolute():
        root = DATA_YAML.parent / root
    return (root / split_path).resolve()


def label_path_for_image(image_path: Path) -> Path:
    parts = list(image_path.parts)
    if "images" in parts:
        parts[parts.index("images")] = "labels"
        return Path(*parts).with_suffix(".txt")
    return image_path.with_suffix(".txt")


def image_path_for_label(label_path: Path) -> Path | None:
    parts = list(label_path.parts)
    if "labels" in parts:
        parts[parts.index("labels")] = "images"
        stem_path = Path(*parts).with_suffix("")
        for ext in IMAGE_EXTS:
            candidate = stem_path.with_suffix(ext)
            if candidate.exists():
                return candidate
    return None


def iter_images(image_dir: Path) -> list[Path]:
    if not image_dir.exists():
        return []
    return sorted(p for p in image_dir.rglob("*") if p.is_file() and p.suffix.lower() in IMAGE_EXTS)


def validate_label_file(label_path: Path, expected_cols: int) -> list[str]:
    errors = []
    for line_no, line in enumerate(label_path.read_text(encoding="utf-8").splitlines(), start=1):
        stripped = line.strip()
        if not stripped:
            continue
        parts = stripped.split()
        if len(parts) != expected_cols:
            hint = ""
            if len(parts) == 5 and expected_cols > 5:
                hint = " (old bbox-only SC label; recollect SC data with 4 keypoints)"
            errors.append(f"{label_path}:{line_no}: expected {expected_cols} columns, got {len(parts)}{hint}")
            continue
        try:
            class_id = int(float(parts[0]))
            values = [float(v) for v in parts[1:]]
        except ValueError:
            errors.append(f"{label_path}:{line_no}: non-numeric value")
            continue
        if class_id not in CLASS_NAMES:
            errors.append(f"{label_path}:{line_no}: unknown class_id {class_id}")
        if any(v < 0.0 or v > 1.0 for v in values):
            errors.append(f"{label_path}:{line_no}: bbox/keypoint values must be normalized 0..1")
    return errors


DATASET_DIR = WS_ROOT / "data" / "yolo" / "approach" / "SC"
DATA_YAML = DATASET_DIR / "data.yaml"
print(f"Checking dataset: {DATASET_DIR}")

cfg = yaml.safe_load(DATA_YAML.read_text(encoding="utf-8"))
expected_cols = 5 + len(KEYPOINT_NAMES) * KEYPOINT_DIMS
all_errors = []

for split in ["train", "val"]:
    image_dir = resolve_split_dir(cfg, split)
    images = iter_images(image_dir)
    labels = [label_path_for_image(p) for p in images]
    missing_labels = [p for p in labels if not p.exists()]
    existing_labels = [p for p in labels if p.exists()]

    label_dir = Path(str(image_dir).replace("/images/", "/labels/"))
    orphan_labels = []
    if label_dir.exists():
        orphan_labels = [p for p in label_dir.rglob("*.txt") if image_path_for_label(p) is None]

    print(f"{split}: images={len(images)}, labels={len(existing_labels)}, missing_labels={len(missing_labels)}, orphan_labels={len(orphan_labels)}")
    if not images:
        all_errors.append(f"{split}: no images under {image_dir}")
    all_errors.extend(f"missing label: {p}" for p in missing_labels[:20])
    all_errors.extend(f"orphan label: {p}" for p in orphan_labels[:20])
    for label_path in existing_labels[:]:
        all_errors.extend(validate_label_file(label_path, expected_cols))

if all_errors:
    preview = "\n".join(all_errors[:50])
    raise ValueError(f"Label check failed with {len(all_errors)} errors.\n{preview}")

print(f"OK: expected label columns = {expected_cols}")
# Out:
# Checking dataset: /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC
# train: images=1017, labels=1017, missing_labels=0, orphan_labels=0
# val: images=115, labels=115, missing_labels=0, orphan_labels=0
# OK: expected label columns = 13

# %% [markdown]
# ## Train
#
# `MODEL_NAME`은 pose 모델이어야 합니다. 기본은 repo에 있는 `yolo11s-pose.pt`입니다.

# %%
from ultralytics import YOLO


LOCAL_MODEL = SRC_ROOT / "ais" / "ais_yolo_train" / "yolo11s-pose.pt"
MODEL_NAME = str(LOCAL_MODEL) if LOCAL_MODEL.exists() else "yolo11s-pose.pt"
OUTPUT_DIR = WS_ROOT / "model" / "ais_yolo" / "approach" / "SC"

EPOCHS = 100
IMGSZ = 640
BATCH = 16
DEVICE = 0  # CPU는 "cpu"
WORKERS = 8
PATIENCE = 20

model = YOLO(MODEL_NAME)
results = model.train(
    data=str(DATA_YAML),
    epochs=EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    project=str(OUTPUT_DIR.parent),
    name=OUTPUT_DIR.name,
    patience=PATIENCE,
    save=True,
    save_period=10,
    plots=True,
    device=DEVICE,
    workers=WORKERS,
)

best_pt = OUTPUT_DIR / "weights" / "best.pt"
print(f"best.pt: {best_pt}")
# Out:
# Ultralytics 8.4.48 🚀 Python-3.10.12 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24115MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/whyz/aic_sejong/ws_aic/src/ais/ais_yolo_train/yolo11s-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=SC, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml kpt_shape=[17, 3] with kpt_shape=[4, 2]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1   1106667  ultralytics.nn.modules.head.Pose             [1, [4, 2], 16, None, [128, 256, 512]]
# YOLO11s-pose summary: 197 layers, 9,715,051 parameters, 9,715,035 gradients, 22.5 GFLOPs
#
# Transferred 505/541 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3246.3±1190.0 MB/s, size: 95.9 KB)
# train: Scanning /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/labels/train... 1017 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1017/1017 1.7Kit/s 0.6s1ss
# train: New cache created: /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1090.6±863.8 MB/s, size: 87.7 KB)
# val: Scanning /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/labels/val... 115 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 115/115 1.7Kit/s 0.1s
# val: New cache created: /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/labels/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 87 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# Plotting labels to /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.03G      2.372      6.029          0      2.482      1.241         12        640: 100% ━━━━━━━━━━━━ 64/64 3.6it/s 17.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.3it/s 3.2s0.3ss
#                    all        115        115      0.595      0.591      0.542      0.218     0.0545     0.0609      0.011    0.00262
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.33G      1.915      3.173          0      1.098      1.078         10        640: 100% ━━━━━━━━━━━━ 64/64 9.2it/s 7.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.6it/s 0.4s0.2s
#                    all        115        115     0.0292      0.139    0.00541    0.00111      0.014     0.0783    0.00154   0.000245
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.33G      1.896      2.363          0      1.052      1.068          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.8it/s 0.4s0.2s
#                    all        115        115      0.516      0.733      0.617       0.29      0.564      0.687      0.658      0.327
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.33G       1.65      1.798          0     0.9053      1.016         13        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.7it/s 0.4s0.2s
#                    all        115        115      0.928       0.78      0.856      0.533      0.887       0.82      0.908      0.647
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      4.33G      1.563      1.456          0     0.8411     0.9808         19        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.9it/s 0.4s0.2s
#                    all        115        115      0.988      0.707      0.848      0.501      0.964      0.689      0.844      0.595
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.33G      1.555      1.385          0     0.8763     0.9858         13        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.9it/s 0.4s0.2s
#                    all        115        115      0.842      0.883        0.9      0.504      0.833      0.852      0.834      0.729
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.33G      1.584      1.469          0     0.8629     0.9899         14        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.881      0.837      0.865      0.545      0.883      0.849      0.891      0.713
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.33G      1.453      1.178          0     0.7856     0.9562         12        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.0it/s 0.4s.2s
#                    all        115        115      0.749      0.809      0.808      0.507      0.715      0.774      0.773      0.632
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      4.33G      1.361     0.9835          0     0.7416     0.9338         10        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.897      0.861      0.914      0.655      0.929      0.861      0.948       0.89
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.33G      1.207     0.7496          0      0.664     0.9086         14        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.962      0.887      0.905      0.685      0.954      0.922      0.958      0.905
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.33G      1.189     0.7012          0     0.6501     0.8829         10        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 9.9it/s 0.4s0.2s
#                    all        115        115      0.911      0.913      0.925      0.685      0.919      0.922      0.951      0.864
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.33G      1.136     0.6084          0     0.6335     0.8773         10        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.946      0.939      0.933      0.736      0.946      0.939      0.967      0.934
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.33G      1.067       0.57          0     0.5996     0.8788         18        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.971      0.904      0.933      0.775      0.971      0.904      0.967      0.942
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.33G      1.054     0.4722          0     0.5868     0.8635         10        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.987      0.939      0.935      0.699      0.991      0.945      0.979      0.961
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.33G      1.012     0.4342          0     0.5699       0.86         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.0it/s 0.4s.2s
#                    all        115        115      0.935      0.913      0.912      0.701      0.962      0.939      0.959      0.937
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.33G      1.022     0.5286          0     0.5731     0.8595         10        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.968      0.939      0.933      0.736      0.973      0.939      0.961      0.939
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.33G     0.9461     0.4494          0     0.5383     0.8419         17        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.958      0.939      0.933      0.752      0.994      0.974      0.975      0.937
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      4.33G     0.9615     0.4144          0     0.5313     0.8529         13        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.0it/s 0.4s.2s
#                    all        115        115       0.99      0.891      0.933      0.728      0.941      0.965      0.971      0.953
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.33G     0.9561     0.3658          0     0.5308     0.8454         14        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.995      0.922      0.935      0.682      0.995      0.922      0.965       0.95
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      4.33G     0.9031     0.3908          0     0.5063     0.8373         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.971      0.939      0.933      0.772      0.973      0.947      0.979      0.956
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.33G     0.8193      0.317          0     0.4755     0.8292         12        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.994      0.939      0.935      0.801      0.994      0.939       0.97       0.95
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      4.33G     0.8792     0.3338          0     0.4954     0.8388         11        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115          1      0.912      0.925       0.76      0.986      0.939      0.959      0.938
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      4.33G     0.8161     0.3458          0     0.4749     0.8267          6        640: 100% ━━━━━━━━━━━━ 64/64 9.5it/s 6.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.937      0.939      0.933      0.776      0.937      0.939      0.968      0.954
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      4.33G      0.807     0.3148          0      0.475      0.823          7        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.989      0.939      0.935       0.79      0.982      0.964      0.984       0.97
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      4.33G     0.8069     0.2609          0     0.4591     0.8301         11        640: 100% ━━━━━━━━━━━━ 64/64 9.6it/s 6.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.808      0.997      0.939      0.972      0.954
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      4.33G     0.7768     0.2968          0     0.4595     0.8298         11        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.984      0.939      0.935      0.797      0.984      0.939      0.969      0.948
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      4.33G     0.7939     0.2823          0     0.4569     0.8279         15        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.982      0.924      0.935      0.754      0.965      0.946       0.98      0.951
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      4.33G     0.7806     0.2721          0     0.4478     0.8184         14        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.982      0.925      0.935      0.812      0.982      0.925      0.972      0.953
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      4.33G     0.8048     0.2492          0     0.4493     0.8247         13        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.804      0.999      0.939      0.956      0.951
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      4.33G     0.7426      0.214          0     0.4463     0.8156          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.803      0.999      0.939      0.945      0.938
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      4.33G     0.7003     0.2186          0     0.4276     0.8111         10        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935       0.82      0.998      0.939      0.971      0.957
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      4.33G     0.7676     0.2305          0     0.4421     0.8165         15        640: 100% ━━━━━━━━━━━━ 64/64 9.2it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.0it/s 0.4s.2s
#                    all        115        115      0.947      0.929      0.933      0.789      0.957      0.939      0.968      0.953
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      4.33G     0.7267     0.2088          0     0.4405     0.8222         12        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.4s
#                    all        115        115      0.967      0.939      0.935      0.805      0.967      0.939      0.968      0.949
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      4.33G     0.7152     0.1971          0     0.4245     0.8079         12        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.817      0.998      0.939      0.972      0.951
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      4.33G      0.688     0.2182          0     0.4194     0.8075          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.993      0.939      0.935      0.821      0.993      0.939      0.935      0.935
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      4.33G     0.7195     0.2143          0     0.4184     0.8132         16        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.0it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.793      0.997      0.939      0.986      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      4.33G     0.6847     0.1772          0     0.4121     0.8029         12        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115       0.99      0.939      0.935      0.833      0.988      0.974      0.975      0.963
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      4.33G      0.697     0.2394          0     0.4249     0.8073         15        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.989      0.939      0.935      0.786      0.989      0.939      0.941      0.939
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      4.33G     0.6978     0.2074          0     0.4262     0.8066          7        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.825      0.999      0.939      0.943      0.937
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      4.33G     0.6328     0.1628          0     0.3918     0.8014         12        640: 100% ━━━━━━━━━━━━ 64/64 9.2it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.996      0.939      0.935       0.84      0.996      0.939      0.973      0.962
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      4.33G     0.6443     0.1622          0     0.3947     0.8052         19        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.824      0.999      0.939       0.95      0.946
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      4.33G     0.6791     0.2084          0     0.4107      0.811         11        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.837      0.999      0.939      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      4.33G       0.68     0.2089          0     0.4091     0.8067         14        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.831      0.999      0.939      0.966      0.958
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      4.33G     0.6509     0.1858          0     0.4025     0.8038         12        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.988      0.939      0.935      0.828      0.988      0.939      0.974      0.951
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      4.33G     0.6407     0.2001          0     0.3907     0.7955         17        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.987      0.939      0.935      0.834      0.962      0.974      0.974      0.963
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      4.33G     0.6275     0.1684          0     0.3928      0.804         16        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.979      0.939      0.934      0.821      0.979      0.939      0.972       0.96
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      4.33G     0.6155     0.1778          0     0.3897      0.803         12        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.841      0.999      0.939      0.972      0.958
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      4.33G     0.6115     0.1567          0     0.3809     0.8063         11        640: 100% ━━━━━━━━━━━━ 64/64 9.2it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.829      0.999      0.939      0.978      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      4.33G      0.585     0.1318          0     0.3775     0.7965         14        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.994      0.939      0.935      0.845      0.994      0.939      0.974      0.956
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      4.33G     0.5979     0.1456          0     0.3783     0.7951         13        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.4s
#                    all        115        115      0.999      0.939      0.935      0.841      0.999      0.939      0.973      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      4.33G     0.6179     0.1398          0     0.3877     0.7996         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.856          1      0.948      0.975      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      4.33G     0.5752     0.1666          0     0.3742     0.8027         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115       0.99      0.939      0.935      0.844       0.99      0.939      0.973      0.963
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      4.33G     0.5636     0.1189          0     0.3653     0.7954         14        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.4s
#                    all        115        115      0.998      0.939      0.935       0.86      0.974      0.974      0.974       0.95
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      4.33G     0.5885     0.1176          0     0.3692      0.798          8        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.996      0.939      0.935      0.853      0.996      0.939      0.972      0.957
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      4.33G     0.5603     0.1299          0      0.368     0.7948         11        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.858      0.999      0.939      0.971      0.961
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      4.33G     0.5411     0.1316          0     0.3612     0.7907         14        640: 100% ━━━━━━━━━━━━ 64/64 9.2it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.873      0.999      0.939      0.974      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      4.33G     0.5695     0.1233          0      0.365     0.8028          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935       0.86          1      0.955      0.965      0.953
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      4.33G     0.5503     0.1362          0     0.3587     0.7882         12        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.7it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.855      0.999      0.939      0.954      0.948
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      4.33G     0.5549     0.1273          0     0.3591     0.7917         12        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.857      0.999      0.939      0.975      0.951
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      4.33G     0.5682     0.1283          0     0.3613     0.7984          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.858      0.991      0.963      0.975       0.96
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      4.33G      0.539     0.1097          0     0.3528     0.7983         13        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.4s
#                    all        115        115      0.998      0.939      0.935      0.876      0.998      0.939      0.973      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      4.33G     0.5419     0.1144          0      0.358     0.7892         15        640: 100% ━━━━━━━━━━━━ 64/64 9.1it/s 7.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.865      0.998      0.939      0.973      0.959
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      4.33G      0.522     0.1002          0     0.3548     0.7854         11        640: 100% ━━━━━━━━━━━━ 64/64 9.2it/s 7.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115          1       0.93      0.935      0.878          1       0.93      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      4.33G     0.4936    0.08835          0     0.3318      0.785          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.893      0.997      0.939      0.973      0.954
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      4.33G     0.5025    0.09669          0     0.3321     0.7937         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.866      0.999      0.939      0.974      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      4.33G     0.5159    0.09783          0     0.3428     0.7853         16        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.863      0.998      0.939      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      4.33G     0.5078    0.09864          0     0.3245      0.795         18        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.7it/s 0.4s.4s
#                    all        115        115      0.999      0.939      0.935      0.876      0.999      0.939      0.973      0.958
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      4.33G     0.4893     0.1096          0     0.3294     0.7808         12        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.4s
#                    all        115        115      0.979      0.939      0.935      0.882      0.979      0.939      0.971      0.963
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      4.33G      0.501    0.09367          0     0.3332     0.7782         11        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.8it/s 0.4s.4s
#                    all        115        115      0.992      0.939      0.935      0.885      0.992      0.939      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      4.33G     0.4968     0.0733          0     0.3277     0.7845         11        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.2it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.885      0.998      0.939      0.972       0.96
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      4.33G     0.4674    0.09469          0     0.3255     0.7848         11        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935       0.89      0.999      0.939      0.974      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      4.33G     0.4848     0.1002          0     0.3242     0.7876         14        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.887      0.998      0.939      0.971      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      4.33G     0.4843     0.1054          0     0.3239     0.7854         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.882          1      0.947      0.975      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      4.33G     0.4843    0.09451          0      0.322     0.7882          9        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.883      0.999      0.939      0.972      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      4.33G     0.4575    0.08482          0     0.3156     0.7786         13        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.887          1      0.962      0.984      0.969
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      4.33G     0.4746    0.09089          0     0.3209      0.779         11        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.891      0.997      0.939      0.935      0.935
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      4.33G     0.4919     0.1009          0     0.3267     0.7845         17        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.1it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.889      0.998      0.939      0.974      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      4.33G     0.4679    0.09071          0     0.3152      0.782         14        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.996      0.939      0.935      0.893      0.996      0.939      0.973      0.963
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      4.33G     0.4522    0.08076          0     0.3089     0.7853         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.996      0.939      0.935      0.882      0.996      0.939      0.972      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      4.33G     0.4196    0.07427          0      0.298     0.7776         11        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.7it/s 0.4s.2s
#                    all        115        115          1      0.928      0.935      0.897          1      0.928      0.944      0.943
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      4.33G      0.454    0.06743          0     0.3116     0.7828          8        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.894      0.999      0.939      0.971      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      4.33G      0.441    0.08849          0     0.3042     0.7887         11        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.898      0.997      0.939       0.97      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      4.33G     0.4353    0.07697          0     0.3043     0.7776         17        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.996      0.939      0.935      0.907      0.996      0.939      0.973      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      4.33G     0.4308     0.0718          0     0.2949     0.7756         13        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115          1       0.93      0.935      0.903          1       0.93      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      4.33G     0.4181     0.0645          0     0.2898      0.776         14        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.903      0.998      0.939      0.973      0.962
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      4.33G     0.4184    0.08034          0     0.2899     0.7782          8        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935      0.905      0.999      0.939      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.33G     0.4119    0.06938          0     0.2851     0.7777         12        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.4s
#                    all        115        115          1       0.93      0.935      0.901          1       0.93      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.33G     0.4177    0.06959          0     0.2814      0.779         10        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.7it/s 0.4s.4s
#                    all        115        115          1      0.929      0.935      0.897          1      0.929      0.974      0.968
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.33G     0.3989    0.07206          0     0.2788     0.7777          7        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.5it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.906      0.998      0.939      0.973      0.962
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.33G     0.3996    0.06247          0      0.279      0.782         12        640: 100% ━━━━━━━━━━━━ 64/64 9.3it/s 6.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.907      0.998      0.939      0.974      0.966
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.33G     0.3661    0.05749          0     0.2754     0.7834          9        640: 100% ━━━━━━━━━━━━ 64/64 8.5it/s 7.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.892      0.997      0.939      0.973      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      4.33G     0.3628    0.05097          0     0.2649      0.781          7        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.996      0.939      0.935      0.911      0.996      0.939      0.971      0.963
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.33G     0.3503    0.04204          0     0.2587     0.7757          7        640: 100% ━━━━━━━━━━━━ 64/64 9.5it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.2s
#                    all        115        115      0.999      0.939      0.935       0.91      0.999      0.939      0.974      0.967
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.33G     0.3549    0.04679          0     0.2653     0.7785          8        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.2s
#                    all        115        115      0.997      0.939      0.935      0.901      0.997      0.939      0.962      0.956
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.33G     0.3391    0.03959          0     0.2567     0.7817          8        640: 100% ━━━━━━━━━━━━ 64/64 9.5it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.907      0.998      0.939      0.974      0.966
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.33G      0.327    0.03601          0     0.2506     0.7772          9        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.6it/s 0.4s.7s
#                    all        115        115      0.998      0.939      0.935      0.914      0.998      0.939      0.973      0.968
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.33G     0.3306    0.03952          0     0.2474     0.7822          6        640: 100% ━━━━━━━━━━━━ 64/64 9.5it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.7it/s 0.4s.7s
#                    all        115        115      0.997      0.939      0.935      0.909      0.997      0.939      0.972      0.964
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.33G      0.336    0.03644          0     0.2473     0.7742          7        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.901      0.998      0.939      0.973      0.965
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.33G     0.3232    0.03232          0     0.2431     0.7834          7        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.3it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.916      0.998      0.939      0.973      0.967
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.33G     0.3036    0.03611          0     0.2353     0.7833          8        640: 100% ━━━━━━━━━━━━ 64/64 9.4it/s 6.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 10.4it/s 0.4s.2s
#                    all        115        115      0.998      0.939      0.935      0.915      0.998      0.939      0.973      0.965
#
# 100 epochs completed in 0.213 hours.
# Optimizer stripped from /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC/weights/last.pt, 19.8MB
# Optimizer stripped from /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC/weights/best.pt, 19.8MB
#
# Validating /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC/weights/best.pt...
# Ultralytics 8.4.48 🚀 Python-3.10.12 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3090, 24115MiB)
# YOLO11s-pose summary (fused): 110 layers, 9,699,867 parameters, 0 gradients, 22.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 4.8it/s 0.8s0.3s
#                    all        115        115      0.998      0.939      0.935      0.916      0.998      0.939      0.973      0.967
# Speed: 0.3ms preprocess, 1.8ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC
# best.pt: /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC/weights/best.pt

# %% [markdown]
# ## Resume or validate only
#
# 필요할 때만 아래 셀을 실행합니다.

# %%
# last.pt에서 완전 재개할 때 사용합니다.
# resume_pt = OUTPUT_DIR / "weights" / "last.pt"
# model = YOLO(str(resume_pt))
# results = model.train(resume=True)

# %%
# 학습 없이 검증만 할 때 사용합니다.
# model = YOLO(str(OUTPUT_DIR / "weights" / "best.pt"))
# metrics = model.val(data=str(DATA_YAML), imgsz=IMGSZ, batch=BATCH, device=DEVICE)
# print(metrics)

# %%
# 샘플 이미지 예측 확인용입니다.
import cv2
import matplotlib.pyplot as plt

cfg = yaml.safe_load(DATA_YAML.read_text(encoding="utf-8"))
sample_images = iter_images(resolve_split_dir(cfg, "val")) or iter_images(resolve_split_dir(cfg, "train"))
sample = random.choice(sample_images)
model = YOLO(str(OUTPUT_DIR / "weights" / "best.pt"))
pred = model.predict(
    source=str(sample),
    imgsz=IMGSZ,
    device=DEVICE,
    save=True,
    project=str(OUTPUT_DIR.parent),
    name=f"{OUTPUT_DIR.name}_predict",
)
annotated = pred[0].plot()
plt.figure(figsize=(8, 7))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title(sample.name)
print(sample)
# Out:
# image 1/1 /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/images/val/ep00180_left.jpg: 576x640 1 sc_port, 55.5ms
# Speed: 1.9ms preprocess, 55.5ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
# Results saved to /home/whyz/aic_sejong/ws_aic/model/ais_yolo/approach/SC_predict
# /home/whyz/aic_sejong/ws_aic/data/yolo/approach/SC/images/val/ep00180_left.jpg
